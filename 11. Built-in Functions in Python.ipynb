# %% [markdown]
# # 11. Python Built-in Function
# * __Python has several functions that are readily available for use. These functions are called built-in Functions.__
#
# * __Built- in Functions__
#
# * __A__
#
#  __abs()__
#
#  __all()__
#
#  __any()__
#
#  __any()__
#
#  __ascii()__
#
# * __B__
#
#  __bin()__
#
#  __bool()__
#
#  __breakpoint()__
#
#  __bytearray()__
#
#  __byte()__
#
# * __C__
#
#  __callable()__
#
#  __chr()__
#
#  __classmethod()__
#
#  __compile()__
#
#  __complex()__
#
# * __D__
#
#  __delattr()__
#  __dict()__
#  __dir()__
#  __divmod()__
#
# * __E__
#
#  __enumerates()__
#
#  __eval()__
#
#  __exec()__
#
# * __F__
#
#  __filter()__
#
#  __float()__
#
#  __format()__
#
#  __frozenset()__
#
# * __G__
#
#  __getattr()__
#
#  __globals()__
#
# * __H__
#
#  __hasattr()__
#
#  __hash()__
#
#  __help()__
#
#  __hex()__
#
# * __I__
#
#  __id()__
#
#  __input()__
#
#  __int()__
#
#  __isinstance()__
#
#  __issubclass()__
#
#  __iter()__
#
# * __L__
#
#  __len()__
#
#  __list()__
#
#  __locals()__
#
# * __M__
#
#  __map()__
#
#  __max()__
#
#  __memoryview()__
#
#  __min()__
#
#
# * __N__
#
#  __next()__
#
# * __O__
#
#  __object()__
#
#  __oct()__
#
#  __open()__
#
#  __ord()__
#
# * __P__
#
#  __pow()__
#
#  __point()__
#
#  __property()__
#
# * __R__
#  __range()__
#
#  __repr()__
#
#  __reversed()__
#
#  __round()__
#
# * __S__
#
#  __set()__
#
#  __setattr()__
#
#  __slice()__
#
#  __sorted()__
#
#  __staticmethod()__
#
#  __str()__
#
#  __sum()__
#
#  __super()__
#
# * __T__
#  __tuple()__
#
#  __type()__
#
#
# * __V__
#
#  __vars()__
#
# * __Z()__
#
#  __zip()__
#
# * ______
#
#  __import()__
